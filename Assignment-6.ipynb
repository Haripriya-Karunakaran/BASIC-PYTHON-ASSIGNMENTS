# %% [markdown]
# ## Assignment - 6

# %% [markdown]
# ### 1. What are escape characters, and how do you use them?

# %% [markdown]
# #### Ans:
# An escape character is a backslash \ followed by the character you want to insert.
# We use them to insert characters that are illegal in a string.

# %%
data = "We have enrolled in \"iNeuron's\" Full Stack Data Science class."
print(data)
# Out:
# We have enrolled in "iNeuron's" Full Stack Data Science class.

# %% [markdown]
# ### 2. What do the escape characters n and t stand for?

# %% [markdown]
# #### Ans:
# /n - Newline,
#
# /t - Tab

# %% [markdown]
# ### 3. What is the way to include backslash characters in a string?

# %% [markdown]
# #### Ans:
# The \ \ escape character will represent the backslash character in a string

# %%
s= "YES \\ NO"
print(s)
# Out:
# YES \ NO

# %% [markdown]
# ### 4. The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the word Howl&#39;s not escaped a problem?

# %% [markdown]
# #### Ans:
# We can repressent a string within the single quote character or within the double quote character. Since we have enclosed the "Howl's Moving Castle" in double quote. hence the single quote character is not a problem

# %% [markdown]
# ### 5. How do you write a string of newlines if you don&#39;t want to use the n character?

# %% [markdown]
# #### Ans:
# Multiline string allow you to use newlines in string without the \n escape character.

# %%
# Example:
a = '''iNeuron full stack
Data Science Course'''
print(a)
# Out:
# iNeuron full stack
# Data Science Course

# %% [markdown]
# ### 6. What are the values of the given expressions?
#
# ### &#39;Hello, world!&#39;[1]
#
# ### &#39;Hello, world!&#39;[0:5]
#
# ### &#39;Hello, world!&#39;[:5]
#
# ### &#39;Hello, world!&#39;[3:]

# %%
# Ans
print('Hello, world!'[1])
print('Hello, world!'[0:5])
print('Hello, world!'[:5])
print('Hello, world!'[3:])
# Out:
# e
# Hello
# Hello
# lo, world!

# %% [markdown]
# ### 7. What are the values of the following expressions?
#
# ### &#39;Hello&#39;.upper()
#
# ### &#39;Hello&#39;.upper().isupper()
#
# ### &#39;Hello&#39;.upper().lower()

# %%
# Ans
print('Hello'.upper())
print('Hello'.upper().isupper())
print('Hello'.upper().lower())
# Out:
# HELLO
# True
# hello

# %% [markdown]
# ### 8. What are the values of the following expressions?
# ### &#39;Remember, remember, the fifth of July.&#39;.split()
# ### &#39;-&#39;.join(&#39;There can only one.&#39;.split())

# %%
# Ans:
print('Remember, remember, the fifth of July.'.split()) 
print('-'.join('There can only one.'.split()))
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
# There-can-only-one.

# %% [markdown]
# ### 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# #### Ans:
# The methods for right-justifying, left-justifying, and centering a string are rjust(), ljust() and center() respectively.

# %% [markdown]
# ### 10. What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# #### Ans:
# The lstrip() and rstrip() methods remove whitesapce characters from the left and right ends of a string respectively
